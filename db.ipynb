# %%
# !pip install pymongo pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('localhost', 27017)
db = client['flask_db']

# %%
collections = {
    'chat_post_task': db.chat_post_task,
    'chat_history': db.chat_history,
    'chat_client_info': db.chat_client_info,
    'chat_in_task': db.chat_in_task
    
}

def fetch_and_format_data(collection):
    data = list(collection.find())
    df = pd.DataFrame(data)
    df = df.loc[:, ~df.columns.duplicated()]
    return df

# %%
chat_post_task_data = fetch_and_format_data(db.chat_post_task)
print("Data from chat_post_task collection:")
display(chat_post_task_data)
# Out:
# Data from chat_post_task collection:
#                         _id  interaction_polite  interaction_dignity  \
# 0  668e0bb27858271b11e68a4c                   1                    0
#
#    interaction_respect  cognitive_demands  cognitive_resources  \
# 0                    0                  4                    4
#
#    affect_valence  affect_arousal  support_effective  support_helpful  \
# 0               1               1                 -1               -1
#
#    support_beneficial  support_adequate  support_sensitive  support_caring  \
# 0                  -1                -1                 -1              -1
#
#    support_understanding  support_supportive  \
# 0                     -1                  -1
#
#                               client_id                            session_id  \
# 0  598bf216-65d6-4f1c-b771-587304ddf396  54e8824c-5cb3-45cd-9602-e818379966be
#
#                 timestamp
# 0 2024-07-10 04:18:58.671

# %%
chat_history_data = fetch_and_format_data(db.chat_history)
print("Data from chat_history collection:")
display(chat_history_data)
# Out:
# Data from chat_history collection:
#                           _id                            session_id  \
# 0    6688503456ba3ac5dd130282  c01bfbc3-bbe4-4b7d-ae70-95778144ea45
# 1    66885067cf8cdc794c727448  9f72f609-072c-4bc6-81a4-894151dc9cec
# 2    6688510bcf8cdc794c72744a  e12fd938-34eb-4575-a049-0bedeef48840
# 3    66885d60404781dafcd9397e  e12fd938-34eb-4575-a049-0bedeef48840
# 4    66885ea6404781dafcd93980  e12fd938-34eb-4575-a049-0bedeef48840
# ..                        ...                                   ...
# 230  668e0f84ade5f0e9b30cde81  41e1d634-7a28-4940-8297-b9d8ee905175
# 231  668e0f84ade5f0e9b30cde82  41e1d634-7a28-4940-8297-b9d8ee905175
# 232  668e0f95ade5f0e9b30cde84  41e1d634-7a28-4940-8297-b9d8ee905175
# 233  668e0f9eade5f0e9b30cde87  41e1d634-7a28-4940-8297-b9d8ee905175
# 234  668e0f9eade5f0e9b30cde88  41e1d634-7a28-4940-8297-b9d8ee905175
#
#                                 client_id  turn_number          sender  \
# ...

# %%
chat_client_info_data = fetch_and_format_data(db.chat_client_info)
print("Data from chat_client_info collection:")
display(chat_client_info_data)
# Out:
# Data from chat_client_info collection:
#                          _id                            session_id  \
# 0   6688248a82130337b1bfea2f  083c065c-d28d-4c7c-aaeb-40ab215dd38b
# 1   6688503456ba3ac5dd130281  c01bfbc3-bbe4-4b7d-ae70-95778144ea45
# 2   66885067cf8cdc794c727447  9f72f609-072c-4bc6-81a4-894151dc9cec
# 3   6688510bcf8cdc794c727449  e12fd938-34eb-4575-a049-0bedeef48840
# 4   66885d60404781dafcd9397d  e12fd938-34eb-4575-a049-0bedeef48840
# ..                       ...                                   ...
# 91  668b82aa6f4793105e38f5f9  bf38782f-43fa-477d-a1e4-20d7381f28af
# 92  668b839c08b7f6ae7c1ac581  bf38782f-43fa-477d-a1e4-20d7381f28af
# 93  668b83d00f7971d2891f4ed9  a2857f5e-3d48-44d0-bdd0-55a1d56bbd9b
# 94  668b84aaf78833389b636024  1cd9dda8-1780-45d3-a4c6-788b74db7bda
# 95  668b85251a4afd3d674738fa  1cd9dda8-1780-45d3-a4c6-788b74db7bda
#
#                                client_id    domain         category grateful  \
# ...

# %%
db.chat_in_task.drop()

# %%
chat_in_task_data = fetch_and_format_data(db.chat_in_task)
print("Data from chat_in_task collection:")
display(chat_in_task_data)
# Out:
# Data from chat_in_task collection:
#                         _id                            session_id  \
# 0  668beab9405e5240600b3d8a  8c461698-64f3-4aac-ae73-02a390d6014a
# 1  668beaba405e5240600b3d8b  8c461698-64f3-4aac-ae73-02a390d6014a
# 2  668beaba405e5240600b3d8c  8c461698-64f3-4aac-ae73-02a390d6014a
# 3  668beaba405e5240600b3d8d  8c461698-64f3-4aac-ae73-02a390d6014a
# 4  668beabc405e5240600b3d8e  8c461698-64f3-4aac-ae73-02a390d6014a
# 5  668beac2405e5240600b3d91  8c461698-64f3-4aac-ae73-02a390d6014a
# 6  668beac5405e5240600b3d92  8c461698-64f3-4aac-ae73-02a390d6014a
# 7  668bead4405e5240600b3d95  8c461698-64f3-4aac-ae73-02a390d6014a
# 8  668bead7405e5240600b3d96  8c461698-64f3-4aac-ae73-02a390d6014a
#
#                               client_id  turn_number      support_type  \
# 0  930b46e6-6412-49a3-aa98-6c625b446e97            1    TYPE_SENTIMENT
# 1  930b46e6-6412-49a3-aa98-6c625b446e97            1      TYPE_TROUBLE
# ...
